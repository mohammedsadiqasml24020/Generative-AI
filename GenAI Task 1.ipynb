# %%
'''Handwritten Digit Classification using MLP (MNIST)

Step 1 – Import Libraries'''
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
import matplotlib.pyplot as plt
import numpy as np
# Out:
# C:\Users\money\anaconda3\envs\cgan_tf215\lib\site-packages\requests\__init__.py:92: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# WARNING:tensorflow:From C:\Users\money\anaconda3\envs\cgan_tf215\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
'''Step 2 – Load the MNIST Dataset'''
# Load MNIST dataset

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

print("Training Images :", x_train.shape)
print("Training Labels :", y_train.shape)

print("Testing Images  :", x_test.shape)
print("Testing Labels  :", y_test.shape)
# Out:
# Training Images : (60000, 28, 28)
# Training Labels : (60000,)
# Testing Images  : (10000, 28, 28)
# Testing Labels  : (10000,)

# %%
'''Step 3 – Display the First Image'''
plt.imshow(x_train[0], cmap="gray")
plt.title(f"Label : {y_train[0]}")
plt.axis("off")
plt.show()

# %%
'''Step 4 – Normalize the Images'''
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
'''Step 5 – Build the MLP'''
model = Sequential([
    
    Flatten(input_shape=(28,28)),
    
    Dense(128, activation="relu"),
    
    Dense(10, activation="softmax")
])
# Out:
# WARNING:tensorflow:From C:\Users\money\anaconda3\envs\cgan_tf215\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
''' step 5: explanation:
28 × 28 Image
↓
Flatten
↓
784 Pixels
↓
128 Neurons
↓
10 Output Neurons
↓
Digit Prediction'''
# Out:
# ' step 5: explanation:\n28 × 28 Image\n↓\nFlatten\n↓\n784 Pixels\n↓\n128 Neurons\n↓\n10 Output Neurons\n↓\nDigit Prediction'

# %%
'''Step 6 – Compile the Model'''
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
# Out:
# WARNING:tensorflow:From C:\Users\money\anaconda3\envs\cgan_tf215\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
'''Step 7 – Train the Model'''
history = model.fit(
    x_train,
    y_train,
    epochs=5,
    verbose=1
)
# Out:
# Epoch 1/5
# WARNING:tensorflow:From C:\Users\money\anaconda3\envs\cgan_tf215\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\money\anaconda3\envs\cgan_tf215\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2615 - accuracy: 0.9243
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1123 - accuracy: 0.9666
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0768 - accuracy: 0.9765
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0573 - accuracy: 0.9826
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0446 - accuracy: 0.9860

# %%
'''Step 8 – Evaluate the Model'''
loss, accuracy = model.evaluate(x_test, y_test)

print("Test Loss :", loss)
print("Test Accuracy :", accuracy)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0795 - accuracy: 0.9752
# Test Loss : 0.07951459288597107
# Test Accuracy : 0.9751999974250793

# %%
'''Step 9 – Display the Input Image'''

# Select any test image
index = 25

# Display the image
plt.imshow(x_test[index], cmap="gray")
plt.title("Input Image")
plt.axis("off")
plt.show()

print("Actual Digit :", y_test[index])
# Out:
# Actual Digit : 0

# %%
'''Step 10 – Predict the Digit'''

# Predict the selected image
prediction = model.predict(x_test[index:index+1])

predicted_digit = np.argmax(prediction)

print("Predicted Digit :", predicted_digit)
# Out:
# 1/1 [==============================] - 0s 29ms/step
# Predicted Digit : 0

# %%
'''Method 2 - Predict a Specific Digit:
Step 1: Find the First Image of a Specific Digit'''

import numpy as np
import matplotlib.pyplot as plt

# Choose the digit you want
digit = 7

# Find the first occurrence of digit 7
index = np.where(y_test == digit)[0][0]

# Display the image
plt.imshow(x_test[index], cmap="gray")
plt.title(f"Actual Digit: {y_test[index]}")
plt.axis("off")
plt.show()

# %%
'''Step 2: Predict the specific input image'''

prediction = model.predict(x_test[index:index+1])

predicted_digit = np.argmax(prediction)

print("Predicted Digit:", predicted_digit)
print("Actual Digit   :", y_test[index])
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Predicted Digit: 7
# Actual Digit   : 7
